# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/My Drive/Dataset/InSDN_DatasetCSV'
# Out:
# /content/drive/My Drive/Dataset/InSDN_DatasetCSV

# %%
import pandas as pd

# Load datasets
df1 = pd.read_csv('OVS.csv')
df2 = pd.read_csv('metasploitable-2.csv')
df3 = pd.read_csv('Normal_data.csv')

# Concatenate datasets along columns axis
concatenated_df = pd.concat([df1, df2,df3], ignore_index=True)

# Save concatenated dataset
concatenated_df.to_csv('concatenated_dataset.csv', index=False)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("concatenated_InSDN_DatasetCSV.csv")

# Drop the specified columns
columns_to_drop = ['Src IP', 'Src Port', 'Dst IP', 'Dst Port', 'Protocol','Timestamp']
df.drop(columns=columns_to_drop, inplace=True)

# Save the modified DataFrame back to a CSV file
df.to_csv("modified_concatenated_InSDN_DatasetCSV.csv", index=False)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("concatenated_InSDN_DatasetCSV.csv")

# Drop the specified columns
columns_to_drop = ['Src IP', 'Src Port', 'Dst IP', 'Dst Port', 'Protocol','Timestamp','Flow ID']
df.drop(columns=columns_to_drop, inplace=True)

# Save the modified DataFrame back to a CSV file
df.to_csv("FlowID_modified_concatenated_InSDN_DatasetCSV.csv", index=False)
